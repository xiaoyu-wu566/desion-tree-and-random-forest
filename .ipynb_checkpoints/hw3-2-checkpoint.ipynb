# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# %%
trainData = pd.read_csv('hw3_question2.csv', delimiter = ',',
                        parse_dates=[0], infer_datetime_format=True)
time = pd.to_datetime('2012-08-25 00:00:00')

# %%
#data_2012_8_25 = trainData.loc[(trainData['Datetime'].apply(lambda x: x.month)==8) &
              #(trainData['Datetime'].apply(lambda x: x.day)==25) &
              #(trainData['Datetime'].apply(lambda x: x.year)==2012), :]

# %% [markdown]
# ### 2(i)

# %%
fig, ax = plt.subplots(1, figsize = (4,4), dpi = 100)
ax.plot((trainData['Datetime']-time).astype('timedelta64[h]'), trainData.iloc[:,1])
ax.set_xlabel('hours')
ax.set_ylabel('number of tickets')
# Out:
# Text(0, 0.5, 'number of tickets')

# %% [markdown]
# ### The number of tickets sold increased over time

# %% [markdown]
# ### (ii.a)

# %%
data_first_month = trainData.iloc[:744,:]
fig, ax = plt.subplots(1, figsize = (4,4), dpi = 100)
ax.plot((data_first_month['Datetime']-time).astype('timedelta64[h]'), data_first_month.iloc[:,1])
ax.set_xlabel('hours')
ax.set_ylabel('number of tickets')
# Out:
# Text(0, 0.5, 'number of tickets')

# %% [markdown]
# ### According to the first month of study, the highest number of tickets was sold around 340 hours.

# %% [markdown]
# ### (ii.e)

# %%
lamda = sum(data_first_month['Count'])/744

# %%
lamda
# Out:
# 3.7876344086021505
